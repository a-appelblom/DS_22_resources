# %% [markdown]
# Import packages

# %%
import pandas as pd
import requests

# %% [markdown]
# Get api urls

# %%
api_key = ""
movie_url = f"https://imdb-api.com/en/API/Top250Movies/{api_key}"
tv_url = f"https://imdb-api.com/en/API/Top250TVs/{api_key}"

# %%
movie_res = requests.get(movie_url)
movie_res
# Out:
# <Response [200]>

# %%
movie_data = movie_res.json()
movie_data
# Out:
# {'items': [{'id': 'tt0111161',
#    'rank': '1',
#    'title': 'The Shawshank Redemption',
#    'fullTitle': 'The Shawshank Redemption (1994)',
#    'year': '1994',
#    'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX128_CR0,12,128,176_AL_.jpg',
#    'crew': 'Frank Darabont (dir.), Tim Robbins, Morgan Freeman',
#    'imDbRating': '9.2',
#    'imDbRatingCount': '2701464'},
#   {'id': 'tt0068646',
#    'rank': '2',
#    'title': 'The Godfather',
#    'fullTitle': 'The Godfather (1972)',
#    'year': '1972',
#    'image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX128_CR0,12,128,176_AL_.jpg',
#    'crew': 'Francis Ford Coppola (dir.), Marlon Brando, Al Pacino',
#    'imDbRating': '9.2',
#    'imDbRatingCount': '1875404'},
#   {'id': 'tt0468569',
#    'rank': '3',
#    'title': 'The Dark Knight',
# ...

# %%
movie_data = movie_data["items"]
movie_data
# Out:
# [{'id': 'tt0111161',
#   'rank': '1',
#   'title': 'The Shawshank Redemption',
#   'fullTitle': 'The Shawshank Redemption (1994)',
#   'year': '1994',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX128_CR0,12,128,176_AL_.jpg',
#   'crew': 'Frank Darabont (dir.), Tim Robbins, Morgan Freeman',
#   'imDbRating': '9.2',
#   'imDbRatingCount': '2701464'},
#  {'id': 'tt0068646',
#   'rank': '2',
#   'title': 'The Godfather',
#   'fullTitle': 'The Godfather (1972)',
#   'year': '1972',
#   'image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX128_CR0,12,128,176_AL_.jpg',
#   'crew': 'Francis Ford Coppola (dir.), Marlon Brando, Al Pacino',
#   'imDbRating': '9.2',
#   'imDbRatingCount': '1875404'},
#  {'id': 'tt0468569',
#   'rank': '3',
#   'title': 'The Dark Knight',
#   'fullTitle': 'The Dark Knight (2008)',
# ...

# %%
movie_df = pd.DataFrame(movie_data)
movie_df
# Out:
#             id rank                     title  \
# 0    tt0111161    1  The Shawshank Redemption
# 1    tt0068646    2             The Godfather
# 2    tt0468569    3           The Dark Knight
# 3    tt0071562    4     The Godfather Part II
# 4    tt0050083    5              12 Angry Men
# ..         ...  ...                       ...
# 245  tt0071411  246               Dersu Uzala
# 246  tt1454029  247                  The Help
# 247  tt0103639  248                   Aladdin
# 248  tt0083987  249                    Gandhi
# 249  tt0099348  250        Dances with Wolves
#
#                            fullTitle  year  \
# 0    The Shawshank Redemption (1994)  1994
# 1               The Godfather (1972)  1972
# 2             The Dark Knight (2008)  2008
# 3       The Godfather Part II (1974)  1974
# 4                12 Angry Men (1957)  1957
# ..                               ...   ...
# 245               Dersu Uzala (1975)  1975
# 246                  The Help (2011)  2011
# ...

# %%
movie_df.to_json("movies.json")

# %%
tv_res = requests.get(tv_url)
tv_data = tv_res.json()
tv_data = tv_data["items"]
tv_df = pd.DataFrame(tv_data)
tv_df.to_json("tv.json")
